# %% [markdown]
# # A Basic Chatbot using RNN(LSTM)

# %% [markdown]
# ### Simple Chatbot Project: Introduction
#
# #### Introduction
#
# In this project, I aimed to develop a simple chatbot using various datasets. Chatbots are software applications designed to interact with users in natural language and perform specific tasks. This project involves creating a chatbot using multiple datasets that serve different purposes.
#
# #### Datasets Used
#
# The following datasets were used for training and testing the chatbot:
#
# 1. **IT Helpdesk Chatbot Dataset**:
#    - **Path**: `/kaggle/input/it-helpdesk-chatbot-dataset/intents.json`
#    - **Description**: This dataset contains various intents and responses for IT helpdesk scenarios.
#
# 2. **Simple Chatbot Dataset**:
#    - **Path**: `/kaggle/input/simple-chatbot-dataset/intents.json`
#    - **Description**: This dataset includes general intents and responses for building a simple chatbot.
#
# 3. **Computer Science Theory QA Dataset**:
#    - **Path**: `/kaggle/input/computer-science-theory-qa-dataset/intents.json`
#    - **Description**: This dataset is designed for questions and answers related to computer science theory.
#
# 4. **Books Dataset**:
#    - **Paths**:
#      - `/kaggle/input/books-dataset/intents.json`
#      - `/kaggle/input/books-dataset/data.csv`
#    - **Description**: This dataset contains intents and data related to books, such as book recommendations and information.
#
# 5. **Chatbot Dataset by Mohammad Nourullahi**:
#    - **Path**: `/kaggle/input/d/mohammadnourullahi/chatbot-dataset/intents.json`
#    - **Description**: A general-purpose chatbot dataset created by Mohammad Nourullahi.
#
# 6. **General Chatbot Dataset**:
#    - **Path**: `/kaggle/input/chatbot-dataset/intents.json`
#    - **Description**: This dataset includes a variety of intents and responses for general chatbot interactions.
#
# 7. **Star Wars Chatbot Dataset**:
#    - **Path**: `/kaggle/input/star-wars-chat-bot/starwarsintents.json`
#    - **Description**: This dataset contains intents and responses related to the Star Wars universe.
#
# #### Objective
#
# The main objective of this project is to create a chatbot capable of handling various types of interactions by leveraging the diverse intents and responses from the provided datasets. The chatbot will be designed to understand user queries and provide appropriate responses, simulating a natural conversation.
#
# #### Methodology
#
# 1. **Data Preparation**: The intents and responses from the datasets were preprocessed and combined into a unified format for training.
# 2. **Model Training**: A machine learning model was trained using the prepared data to recognize different intents and generate appropriate responses.
# 3. **Evaluation**: The chatbot's performance was evaluated using test data to ensure accuracy and reliability.
# 4. **Implementation**: The trained model was implemented into a simple chatbot application, allowing for user interaction.
#
# #### Conclusion
#
# This project demonstrates the development of a simple chatbot using various datasets, showcasing the potential of chatbot technology in different domains. The resulting chatbot can handle a wide range of queries, providing a versatile tool for user interaction.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/it-helpdesk-chatbot-dataset/intents.json
# /kaggle/input/simple-chatbot-dataset/intents.json
# /kaggle/input/computer-science-theory-qa-dataset/intents.json
# /kaggle/input/books-dataset/intents.json
# /kaggle/input/books-dataset/data.csv
# /kaggle/input/d/mohammadnourullahi/chatbot-dataset/intents.json
# /kaggle/input/chatbot-dataset/intents.json
# /kaggle/input/star-wars-chat-bot/starwarsintents.json

# %%
intents = pd.read_json('/kaggle/input/books-dataset/intents.json')

# %%
intents.head()
# Out:
#                                              intents
# 0  {'tag': 'greeting', 'patterns': ['Hello', 'Hi'...
# 1  {'tag': 'goodbye', 'patterns': ['Goodbye', 'By...
# 2  {'tag': 'thanks', 'patterns': ['Thanks', 'Than...
# 3  {'tag': 'book_search', 'patterns': ['Can you r...
# 4  {'tag': 'Fiction', 'patterns': ['Fiction', 'Re...

# %%
intents.shape
# Out:
# (51, 1)

# %%
intents['intents'][0]
# Out:
# {'tag': 'greeting',
#  'patterns': ['Hello',
#   'Hi',
#   'Hey',
#   'Greetings',
#   'Good morning',
#   'Good afternoon',
#   'Good evening'],
#  'responses': ['Hello! How can I help you today?',
#   'Hi there! What can I do for you?',
#   'Hey! What brings you here today?']}

# %%
intents2=pd.read_json("/kaggle/input/simple-chatbot-dataset/intents.json")

# %%
intents2.head()
# Out:
#                                              intents
# 0  {'tag': 'greeting', 'patterns': ['Hi', 'Hey', ...
# 1  {'tag': 'weather', 'patterns': ['What's the we...
# 2  {'tag': 'hobbies', 'patterns': ['What are your...
# 3  {'tag': 'music', 'patterns': ['What's your fav...
# 4  {'tag': 'movies', 'patterns': ['What's a good ...

# %%
intents2.shape
# Out:
# (18, 1)

# %%
intents3=pd.read_json("/kaggle/input/chatbot-dataset/intents.json")

# %%
intents3.head()
# Out:
#                                              intents
# 0  {'tag': 'greeting', 'patterns': ['Hi', 'How ar...
# 1  {'tag': 'goodbye', 'patterns': ['cya', 'see yo...
# 2  {'tag': 'creator', 'patterns': ['what is the n...
# 3  {'tag': 'name', 'patterns': ['name', 'your nam...
# 4  {'tag': 'hours', 'patterns': ['timing of colle...

# %%
intents3.shape
# Out:
# (38, 1)

# %%
intents4=pd.read_json("/kaggle/input/d/mohammadnourullahi/chatbot-dataset/intents.json")

# %%
intents4.head()
# Out:
#                                              intents
# 0  {'tag': 'greeting', 'patterns': ['Hi', 'How ar...
# 1  {'tag': 'goodbye', 'patterns': ['cya', 'see yo...
# 2  {'tag': 'creator', 'patterns': ['what is the n...
# 3  {'tag': 'name', 'patterns': ['name', 'your nam...
# 4  {'tag': 'hours', 'patterns': ['timing of colle...

# %%
intents4.shape
# Out:
# (38, 1)

# %%
intents5=pd.read_json("/kaggle/input/computer-science-theory-qa-dataset/intents.json")
intents5.head()
# Out:
#                                              intents
# 0  {'tag': 'abstraction', 'patterns': ['Explain d...
# 1  {'tag': 'error', 'patterns': ['What is a synta...
# 2  {'tag': 'documentation', 'patterns': ['Explain...
# 3  {'tag': 'testing', 'patterns': ['What is softw...
# 4  {'tag': 'datastructure', 'patterns': ['How do ...

# %%
intents5.shape
# Out:
# (172, 1)

# %%
intents6=pd.read_json("/kaggle/input/it-helpdesk-chatbot-dataset/intents.json")
intents6.head()
# Out:
#                                              intents
# 0  {'tag': 'greeting', 'patterns': ['Hi there', '...
# 1  {'tag': 'goodbye', 'patterns': ['Bye', 'See yo...
# 2  {'tag': 'thanks', 'patterns': ['Thanks', 'Than...
# 3  {'tag': 'noanswer', 'patterns': ['q', 'random'...
# 4  {'tag': 'options', 'patterns': ['How you could...

# %%
intents6.shape
# Out:
# (18, 1)

# %%
intents7=pd.read_json("/kaggle/input/star-wars-chat-bot/starwarsintents.json")
intents7.head()
# Out:
#                                              intents
# 0  {'tag': 'greeting', 'patterns': ['Hi', 'Hey', ...
# 1  {'tag': 'goodbye', 'patterns': ['Bye', 'See yo...
# 2  {'tag': 'thanks', 'patterns': ['Thanks', 'Than...
# 3  {'tag': 'tasks', 'patterns': ['What can you do...
# 4  {'tag': 'alive', 'patterns': ['Are you alive.'...

# %%
# %%bash
# jq -s '[.[].intents] | add | {intents: .}' \
#     /kaggle/input/books-dataset/intents.json \
#     /kaggle/input/chatbot-dataset/intents.json \
#     /kaggle/input/simple-chatbot-dataset/intents.json \
#     /kaggle/input/d/mohammadnourullahi/chatbot-dataset/intents.json \
#     /kaggle/input/computer-science-theory-qa-dataset/intents.json \
#     /kaggle/input/it-helpdesk-chatbot-dataset/intents.json \
#     /kaggle/input/star-wars-chat-bot/starwarsintents.json \
#     > merged_intents.json
# echo "Done"
# Out:
# Done

# %%
import json
import numpy as np
import random
import nltk
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.optimizers import Adam
from nltk.stem import SnowballStemmer

with open('/kaggle/working/merged_intents.json', 'r') as file:
    data = json.load(file)
# Out:
# 2024-07-09 17:03:34.410371: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 17:03:34.410528: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 17:03:34.552923: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
stemmer = SnowballStemmer("english")

words = []
labels = []
docs_x = []
docs_y = []

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        wrds = nltk.word_tokenize(pattern)
        words.extend(wrds)
        docs_x.append(wrds)
        docs_y.append(intent["tag"])

    if intent["tag"] not in labels:
        labels.append(intent["tag"])


words = [stemmer.stem(w.lower()) for w in words if w != "?"]
words = sorted(list(set(words)))

labels = sorted(labels)

training = []
output = []
out_empty = [0 for _ in range(len(labels))]


sequence_length = 5
for i in range(len(docs_x) - sequence_length):
    seq_in = docs_x[i:i + sequence_length]
    seq_out = docs_y[i + sequence_length]

    bag = []
    for seq in seq_in:
        wrds = [stemmer.stem(w.lower()) for w in seq]
        for w in words:
            if w in wrds:
                bag.append(1)
            else:
                bag.append(0)

    output_row = out_empty[:]
    output_row[labels.index(seq_out)] = 1

    training.append(bag)
    output.append(output_row)

training = np.array(training)
training = np.reshape(training, (training.shape[0], sequence_length, len(words)))

output = np.array(output)

# %%
model = Sequential()
model.add(LSTM(550, input_shape=(training.shape[1], training.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(512, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(len(labels), activation='softmax'))

model.summary()
model.compile(Adam(learning_rate=.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(training, output, epochs=500, verbose=1, batch_size=4)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 5, 550)         │     3,025,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5, 550)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 5, 512)         │     2,177,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 5, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 5, 256)         │       787,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 5, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 5, 128)         │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 302)            │        19,630 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,255,638 (23.86 MB)
#  Trainable params: 6,255,638 (23.86 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.0349 - loss: 5.2278
# Epoch 2/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.0352 - loss: 4.4915
# Epoch 3/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.0665 - loss: 4.2451
# Epoch 4/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.0743 - loss: 4.0833
# Epoch 5/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.0983 - loss: 3.7320
# Epoch 6/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1015 - loss: 3.5294
# Epoch 7/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1322 - loss: 3.4145
# Epoch 8/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1097 - loss: 3.4290
# Epoch 9/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1669 - loss: 3.2256
# Epoch 10/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.2067 - loss: 3.0258
# Epoch 11/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.2201 - loss: 2.9029
# Epoch 12/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.2439 - loss: 2.7685
# Epoch 13/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.2809 - loss: 2.6591
# Epoch 14/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.2923 - loss: 2.5246
# Epoch 15/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3639 - loss: 2.3718
# Epoch 16/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3846 - loss: 2.2950
# Epoch 17/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3910 - loss: 2.2631
# Epoch 18/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.4255 - loss: 2.1172
# Epoch 19/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.4460 - loss: 2.0322
# Epoch 20/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.4939 - loss: 1.8713
# Epoch 21/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5221 - loss: 1.8070
# Epoch 22/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.4879 - loss: 1.8742
# Epoch 23/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5136 - loss: 1.7934
# Epoch 24/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5671 - loss: 1.6142
# Epoch 25/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5441 - loss: 1.6882
# Epoch 26/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5802 - loss: 1.5005
# Epoch 27/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6277 - loss: 1.3963
# Epoch 28/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5970 - loss: 1.4469
# Epoch 29/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6022 - loss: 1.3866
# Epoch 30/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6317 - loss: 1.2975
# Epoch 31/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6477 - loss: 1.2361
# Epoch 32/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6486 - loss: 1.2077
# Epoch 33/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6727 - loss: 1.1651
# Epoch 34/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6567 - loss: 1.1822
# Epoch 35/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6682 - loss: 1.1560
# Epoch 36/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6804 - loss: 1.0321
# Epoch 37/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6674 - loss: 1.1083
# Epoch 38/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6834 - loss: 1.0683
# Epoch 39/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7232 - loss: 0.9352
# Epoch 40/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7148 - loss: 0.9488
# Epoch 41/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7191 - loss: 0.9377
# Epoch 42/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7339 - loss: 0.9384
# Epoch 43/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7175 - loss: 0.9114
# Epoch 44/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7243 - loss: 0.9001
# Epoch 45/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7533 - loss: 0.8122
# Epoch 46/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7783 - loss: 0.7432
# Epoch 47/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7548 - loss: 0.8162
# Epoch 48/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7658 - loss: 0.7598
# Epoch 49/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7710 - loss: 0.7657
# Epoch 50/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7807 - loss: 0.7128
# Epoch 51/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7783 - loss: 0.6804
# Epoch 52/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7711 - loss: 0.7534
# Epoch 53/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7994 - loss: 0.6359
# Epoch 54/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7888 - loss: 0.6499
# Epoch 55/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8127 - loss: 0.6404
# Epoch 56/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8071 - loss: 0.6373
# Epoch 57/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8296 - loss: 0.5378
# Epoch 58/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8200 - loss: 0.5690
# Epoch 59/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8262 - loss: 0.5287
# Epoch 60/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8096 - loss: 0.5894
# Epoch 61/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7993 - loss: 0.6440
# Epoch 62/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8258 - loss: 0.5779
# Epoch 63/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8137 - loss: 0.5493
# Epoch 64/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8210 - loss: 0.5592
# Epoch 65/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8424 - loss: 0.4929
# Epoch 66/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8472 - loss: 0.4716
# Epoch 67/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8484 - loss: 0.5082
# Epoch 68/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8701 - loss: 0.4298
# Epoch 69/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8669 - loss: 0.4066
# Epoch 70/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8564 - loss: 0.4396
# Epoch 71/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8476 - loss: 0.4954
# Epoch 72/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8630 - loss: 0.4664
# Epoch 73/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8470 - loss: 0.4256
# Epoch 74/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8727 - loss: 0.3879
# Epoch 75/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8813 - loss: 0.3899
# Epoch 76/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8623 - loss: 0.4277
# Epoch 77/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8762 - loss: 0.3615
# Epoch 78/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8820 - loss: 0.3633
# Epoch 79/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8803 - loss: 0.3797
# Epoch 80/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8971 - loss: 0.3379
# Epoch 81/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8930 - loss: 0.3529
# Epoch 82/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8843 - loss: 0.3962
# Epoch 83/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8810 - loss: 0.3667
# Epoch 84/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8816 - loss: 0.3689
# Epoch 85/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8832 - loss: 0.3438
# Epoch 86/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8918 - loss: 0.3353
# Epoch 87/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8958 - loss: 0.3095
# Epoch 88/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9023 - loss: 0.3159
# Epoch 89/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9112 - loss: 0.2859
# Epoch 90/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9036 - loss: 0.2918
# Epoch 91/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9261 - loss: 0.2605
# Epoch 92/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9274 - loss: 0.2391
# Epoch 93/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9221 - loss: 0.2508
# Epoch 94/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9108 - loss: 0.3176
# Epoch 95/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9212 - loss: 0.2495
# Epoch 96/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9081 - loss: 0.2684
# Epoch 97/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9278 - loss: 0.2386
# Epoch 98/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9451 - loss: 0.1978
# Epoch 99/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9085 - loss: 0.2585
# Epoch 100/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9269 - loss: 0.2380
# Epoch 101/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9456 - loss: 0.2167
# Epoch 102/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9441 - loss: 0.2126
# Epoch 103/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9379 - loss: 0.2232
# Epoch 104/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9269 - loss: 0.2457
# Epoch 105/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9439 - loss: 0.1942
# Epoch 106/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9242 - loss: 0.2272
# Epoch 107/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9526 - loss: 0.1781
# Epoch 108/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9558 - loss: 0.1580
# Epoch 109/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9382 - loss: 0.1784
# Epoch 110/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9299 - loss: 0.2059
# Epoch 111/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9372 - loss: 0.2053
# Epoch 112/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9540 - loss: 0.1592
# Epoch 113/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9584 - loss: 0.1639
# Epoch 114/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9518 - loss: 0.1825
# Epoch 115/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9350 - loss: 0.2104
# Epoch 116/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9606 - loss: 0.1831
# Epoch 117/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9318 - loss: 0.1915
# Epoch 118/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9534 - loss: 0.1627
# Epoch 119/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9556 - loss: 0.1551
# Epoch 120/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9435 - loss: 0.1767
# Epoch 121/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9615 - loss: 0.1347
# Epoch 122/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9601 - loss: 0.1520
# Epoch 123/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9575 - loss: 0.1339
# Epoch 124/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9598 - loss: 0.1297
# Epoch 125/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9474 - loss: 0.1528
# Epoch 126/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9600 - loss: 0.1419
# Epoch 127/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9602 - loss: 0.1426
# Epoch 128/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9662 - loss: 0.1264
# Epoch 129/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9614 - loss: 0.1686
# Epoch 130/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9640 - loss: 0.1517
# Epoch 131/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9475 - loss: 0.1625
# Epoch 132/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9574 - loss: 0.1324
# Epoch 133/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9725 - loss: 0.1018
# Epoch 134/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9640 - loss: 0.1255
# Epoch 135/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9715 - loss: 0.1187
# Epoch 136/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9561 - loss: 0.1418
# Epoch 137/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9693 - loss: 0.1070
# Epoch 138/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9659 - loss: 0.1250
# Epoch 139/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9663 - loss: 0.1101
# Epoch 140/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9780 - loss: 0.0865
# Epoch 141/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9772 - loss: 0.0895
# Epoch 142/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9779 - loss: 0.0843
# Epoch 143/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9644 - loss: 0.1157
# Epoch 144/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9708 - loss: 0.0942
# Epoch 145/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9575 - loss: 0.1414
# Epoch 146/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9781 - loss: 0.0929
# Epoch 147/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9805 - loss: 0.0760
# Epoch 148/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9694 - loss: 0.0968
# Epoch 149/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9694 - loss: 0.0910
# Epoch 150/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9737 - loss: 0.0879
# Epoch 151/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9767 - loss: 0.1019
# Epoch 152/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9727 - loss: 0.0928
# Epoch 153/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9857 - loss: 0.0589
# Epoch 154/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9840 - loss: 0.0623
# Epoch 155/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9735 - loss: 0.1063
# Epoch 156/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9765 - loss: 0.0925
# Epoch 157/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9709 - loss: 0.0981
# Epoch 158/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9860 - loss: 0.0640
# Epoch 159/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9842 - loss: 0.0596
# Epoch 160/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9849 - loss: 0.0592
# Epoch 161/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9816 - loss: 0.0754
# Epoch 162/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9772 - loss: 0.0917
# Epoch 163/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9931 - loss: 0.0480
# Epoch 164/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9855 - loss: 0.0767
# Epoch 165/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9891 - loss: 0.0544
# Epoch 166/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9737 - loss: 0.0986
# Epoch 167/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9722 - loss: 0.0988
# Epoch 168/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9782 - loss: 0.0929
# Epoch 169/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9846 - loss: 0.0565
# Epoch 170/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9842 - loss: 0.0549
# Epoch 171/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9897 - loss: 0.0401
# Epoch 172/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9854 - loss: 0.0423
# Epoch 173/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9842 - loss: 0.0690
# Epoch 174/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9875 - loss: 0.0505
# Epoch 175/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9859 - loss: 0.0593
# Epoch 176/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9763 - loss: 0.0689
# Epoch 177/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9748 - loss: 0.0858
# Epoch 178/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9828 - loss: 0.0670
# Epoch 179/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9901 - loss: 0.0525
# Epoch 180/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9901 - loss: 0.0353
# Epoch 181/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9961 - loss: 0.0260
# Epoch 182/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9940 - loss: 0.0410
# Epoch 183/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9941 - loss: 0.0282
# Epoch 184/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9903 - loss: 0.0443
# Epoch 185/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9767 - loss: 0.0813
# Epoch 186/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9877 - loss: 0.0549
# Epoch 187/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9821 - loss: 0.0707
# Epoch 188/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9806 - loss: 0.0950
# Epoch 189/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9916 - loss: 0.0645
# Epoch 190/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9877 - loss: 0.0531
# Epoch 191/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9889 - loss: 0.0596
# Epoch 192/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9864 - loss: 0.0672
# Epoch 193/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9727 - loss: 0.0958
# Epoch 194/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9764 - loss: 0.0750
# Epoch 195/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9826 - loss: 0.0593
# Epoch 196/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9823 - loss: 0.0634
# Epoch 197/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9859 - loss: 0.0792
# Epoch 198/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9876 - loss: 0.0508
# Epoch 199/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9874 - loss: 0.0544
# Epoch 200/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9908 - loss: 0.0385
# Epoch 201/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9870 - loss: 0.0467
# Epoch 202/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9859 - loss: 0.0432
# Epoch 203/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9910 - loss: 0.0340
# Epoch 204/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9887 - loss: 0.0498
# Epoch 205/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9822 - loss: 0.0681
# Epoch 206/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9822 - loss: 0.0887
# Epoch 207/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9874 - loss: 0.0572
# Epoch 208/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9884 - loss: 0.0527
# Epoch 209/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9882 - loss: 0.0509
# Epoch 210/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9930 - loss: 0.0295
# Epoch 211/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9941 - loss: 0.0268
# Epoch 212/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9984 - loss: 0.0186
# Epoch 213/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9966 - loss: 0.0161
# Epoch 214/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9956 - loss: 0.0245
# Epoch 215/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9919 - loss: 0.0845
# Epoch 216/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9786 - loss: 0.0779
# Epoch 217/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9820 - loss: 0.0744
# Epoch 218/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9770 - loss: 0.0738
# Epoch 219/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9856 - loss: 0.0602
# Epoch 220/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9869 - loss: 0.0546
# Epoch 221/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9804 - loss: 0.0793
# Epoch 222/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9885 - loss: 0.0394
# Epoch 223/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9867 - loss: 0.0501
# Epoch 224/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9926 - loss: 0.0391
# Epoch 225/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9859 - loss: 0.0382
# Epoch 226/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9812 - loss: 0.0724
# Epoch 227/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9930 - loss: 0.0308
# Epoch 228/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9930 - loss: 0.0277
# Epoch 229/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9800 - loss: 0.0641
# Epoch 230/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9847 - loss: 0.0589
# Epoch 231/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9859 - loss: 0.0475
# Epoch 232/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9933 - loss: 0.0280
# Epoch 233/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9959 - loss: 0.0178
# Epoch 234/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9964 - loss: 0.0186
# Epoch 235/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9961 - loss: 0.0236
# Epoch 236/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9989 - loss: 0.0131
# Epoch 237/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9978 - loss: 0.0133
# Epoch 238/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9944 - loss: 0.0169
# Epoch 239/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9883 - loss: 0.0530
# Epoch 240/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9887 - loss: 0.0431
# Epoch 241/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9871 - loss: 0.0746
# Epoch 242/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9775 - loss: 0.0764
# Epoch 243/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9863 - loss: 0.0725
# Epoch 244/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9885 - loss: 0.0463
# Epoch 245/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9867 - loss: 0.0422
# Epoch 246/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9918 - loss: 0.0295
# Epoch 247/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9951 - loss: 0.0285
# Epoch 248/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9969 - loss: 0.0214
# Epoch 249/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9961 - loss: 0.0216
# Epoch 250/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9876 - loss: 0.0585
# Epoch 251/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9701 - loss: 0.1222
# Epoch 252/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9882 - loss: 0.0554
# Epoch 253/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9921 - loss: 0.0299
# Epoch 254/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9937 - loss: 0.0256
# Epoch 255/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9969 - loss: 0.0226
# Epoch 256/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9900 - loss: 0.0299
# Epoch 257/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9950 - loss: 0.0381
# Epoch 258/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9939 - loss: 0.0258
# Epoch 259/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9921 - loss: 0.0260
# Epoch 260/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9735 - loss: 0.1132
# Epoch 261/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9884 - loss: 0.0491
# Epoch 262/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9969 - loss: 0.0191
# Epoch 263/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9942 - loss: 0.0190
# Epoch 264/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9964 - loss: 0.0194
# Epoch 265/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9927 - loss: 0.0252
# Epoch 266/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9949 - loss: 0.0230
# Epoch 267/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9989 - loss: 0.0131
# Epoch 268/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9935 - loss: 0.0177
# Epoch 269/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9974 - loss: 0.0155
# Epoch 270/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9855 - loss: 0.0498
# Epoch 271/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9908 - loss: 0.0522
# Epoch 272/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9860 - loss: 0.0507
# Epoch 273/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9949 - loss: 0.0248
# Epoch 274/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9944 - loss: 0.0234
# Epoch 275/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9970 - loss: 0.0176
# Epoch 276/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9975 - loss: 0.0139
# Epoch 277/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9864 - loss: 0.0491
# Epoch 278/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9937 - loss: 0.0255
# Epoch 279/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9930 - loss: 0.0365
# Epoch 280/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9893 - loss: 0.0563
# Epoch 281/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9838 - loss: 0.0615
# Epoch 282/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9918 - loss: 0.0389
# Epoch 283/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9940 - loss: 0.0353
# Epoch 284/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9934 - loss: 0.0299
# Epoch 285/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9949 - loss: 0.0184
# Epoch 286/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9884 - loss: 0.0458
# Epoch 287/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9888 - loss: 0.0534
# Epoch 288/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9859 - loss: 0.0506
# Epoch 289/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9936 - loss: 0.0319
# Epoch 290/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9928 - loss: 0.0199
# Epoch 291/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9978 - loss: 0.0140
# Epoch 292/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9971 - loss: 0.0160
# Epoch 293/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9924 - loss: 0.0333
# Epoch 294/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9961 - loss: 0.0131
# Epoch 295/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9933 - loss: 0.0194
# Epoch 296/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9880 - loss: 0.0416
# Epoch 297/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9953 - loss: 0.0226
# Epoch 298/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9918 - loss: 0.0287
# Epoch 299/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9924 - loss: 0.0251
# Epoch 300/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9990 - loss: 0.0131
# Epoch 301/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9931 - loss: 0.0247
# Epoch 302/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9912 - loss: 0.0282
# Epoch 303/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9950 - loss: 0.0161
# Epoch 304/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9912 - loss: 0.0324
# Epoch 305/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9887 - loss: 0.0342
# Epoch 306/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9869 - loss: 0.0403
# Epoch 307/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9910 - loss: 0.0459
# Epoch 308/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9923 - loss: 0.0236
# Epoch 309/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9954 - loss: 0.0281
# Epoch 310/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9981 - loss: 0.0109
# Epoch 311/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9985 - loss: 0.0111
# Epoch 312/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9956 - loss: 0.0153
# Epoch 313/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9872 - loss: 0.0823
# Epoch 314/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9942 - loss: 0.0281
# Epoch 315/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9906 - loss: 0.0523
# Epoch 316/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9920 - loss: 0.0541
# Epoch 317/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9995 - loss: 0.0139
# Epoch 318/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9954 - loss: 0.0183
# Epoch 319/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9973 - loss: 0.0224
# Epoch 320/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9939 - loss: 0.0162
# Epoch 321/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9983 - loss: 0.0118
# Epoch 322/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9889 - loss: 0.0729
# Epoch 323/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9838 - loss: 0.0706
# Epoch 324/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9943 - loss: 0.0362
# Epoch 325/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9883 - loss: 0.0379
# Epoch 326/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9905 - loss: 0.0436
# Epoch 327/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9943 - loss: 0.0252
# Epoch 328/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9965 - loss: 0.0219
# Epoch 329/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9945 - loss: 0.0307
# Epoch 330/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9980 - loss: 0.0116
# Epoch 331/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9963 - loss: 0.0194
# Epoch 332/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9943 - loss: 0.0238
# Epoch 333/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9972 - loss: 0.0128
# Epoch 334/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9979 - loss: 0.0097
# Epoch 335/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9881 - loss: 0.0400
# Epoch 336/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9989 - loss: 0.0097
# Epoch 337/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9960 - loss: 0.0161
# Epoch 338/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9952 - loss: 0.0253
# Epoch 339/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9961 - loss: 0.0119
# Epoch 340/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9899 - loss: 0.0370
# Epoch 341/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9920 - loss: 0.0420
# Epoch 342/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9942 - loss: 0.0193
# Epoch 343/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9950 - loss: 0.0237
# Epoch 344/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9928 - loss: 0.0557
# Epoch 345/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9904 - loss: 0.0365
# Epoch 346/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9950 - loss: 0.0184
# Epoch 347/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9977 - loss: 0.0176
# Epoch 348/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9953 - loss: 0.0280
# Epoch 349/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9938 - loss: 0.0315
# Epoch 350/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9956 - loss: 0.0249
# Epoch 351/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9950 - loss: 0.0190
# Epoch 352/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9859 - loss: 0.0502
# Epoch 353/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9934 - loss: 0.0590
# Epoch 354/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9964 - loss: 0.0148
# Epoch 355/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9970 - loss: 0.0149
# Epoch 356/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9940 - loss: 0.0250
# Epoch 357/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9922 - loss: 0.0260
# Epoch 358/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9948 - loss: 0.0176
# Epoch 359/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9942 - loss: 0.0188
# Epoch 360/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9941 - loss: 0.0177
# Epoch 361/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9944 - loss: 0.0266
# Epoch 362/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9933 - loss: 0.0223
# Epoch 363/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9949 - loss: 0.0174
# Epoch 364/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9948 - loss: 0.0198
# Epoch 365/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9959 - loss: 0.0144
# Epoch 366/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9982 - loss: 0.0135
# Epoch 367/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9950 - loss: 0.0162
# Epoch 368/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9952 - loss: 0.0176
# Epoch 369/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9954 - loss: 0.0154
# Epoch 370/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9935 - loss: 0.0313
# Epoch 371/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9989 - loss: 0.0104
# Epoch 372/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9903 - loss: 0.0244
# Epoch 373/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9906 - loss: 0.0247
# Epoch 374/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9934 - loss: 0.0217
# Epoch 375/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9961 - loss: 0.0196
# Epoch 376/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9940 - loss: 0.0252
# Epoch 377/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9965 - loss: 0.0114
# Epoch 378/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9955 - loss: 0.0368
# Epoch 379/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9952 - loss: 0.0163
# Epoch 380/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9942 - loss: 0.0298
# Epoch 381/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9950 - loss: 0.0151
# Epoch 382/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9964 - loss: 0.0150
# Epoch 383/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9903 - loss: 0.0347
# Epoch 384/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9920 - loss: 0.0314
# Epoch 385/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9973 - loss: 0.0127
# Epoch 386/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9972 - loss: 0.0168
# Epoch 387/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9957 - loss: 0.0180
# Epoch 388/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9916 - loss: 0.0174
# Epoch 389/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9963 - loss: 0.0173
# Epoch 390/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9975 - loss: 0.0125
# Epoch 391/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9946 - loss: 0.0169
# Epoch 392/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9953 - loss: 0.0160
# Epoch 393/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9974 - loss: 0.0136
# Epoch 394/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9976 - loss: 0.0130
# Epoch 395/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9967 - loss: 0.0220
# Epoch 396/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9956 - loss: 0.0172
# Epoch 397/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9945 - loss: 0.0200
# Epoch 398/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9994 - loss: 0.0056
# Epoch 399/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9966 - loss: 0.0081
# Epoch 400/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9960 - loss: 0.0115
# Epoch 401/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9952 - loss: 0.0154
# Epoch 402/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9939 - loss: 0.0191
# Epoch 403/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9966 - loss: 0.0146
# Epoch 404/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9980 - loss: 0.0151
# Epoch 405/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9974 - loss: 0.0096
# Epoch 406/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9925 - loss: 0.0173
# Epoch 407/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9968 - loss: 0.0117
# Epoch 408/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9955 - loss: 0.0214
# Epoch 409/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9926 - loss: 0.0218
# Epoch 410/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9937 - loss: 0.0237
# Epoch 411/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9933 - loss: 0.0216
# Epoch 412/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9939 - loss: 0.0236
# Epoch 413/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9864 - loss: 0.0444
# Epoch 414/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9939 - loss: 0.0195
# Epoch 415/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9886 - loss: 0.0438
# Epoch 416/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9957 - loss: 0.0129
# Epoch 417/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9970 - loss: 0.0099
# Epoch 418/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9973 - loss: 0.0103
# Epoch 419/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9993 - loss: 0.0056
# Epoch 420/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9920 - loss: 0.0190
# Epoch 421/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9894 - loss: 0.0324
# Epoch 422/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9891 - loss: 0.0249
# Epoch 423/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9937 - loss: 0.0155
# Epoch 424/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9994 - loss: 0.0118
# Epoch 425/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9898 - loss: 0.0458
# Epoch 426/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9940 - loss: 0.0114
# Epoch 427/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9950 - loss: 0.0233
# Epoch 428/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9937 - loss: 0.0133
# Epoch 429/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9879 - loss: 0.0954
# Epoch 430/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9983 - loss: 0.0097
# Epoch 431/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9955 - loss: 0.0128
# Epoch 432/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9974 - loss: 0.0071
# Epoch 433/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9937 - loss: 0.0204
# Epoch 434/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9967 - loss: 0.0197
# Epoch 435/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9889 - loss: 0.0370
# Epoch 436/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9941 - loss: 0.0324
# Epoch 437/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9936 - loss: 0.0227
# Epoch 438/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9967 - loss: 0.0140
# Epoch 439/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9986 - loss: 0.0130
# Epoch 440/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9958 - loss: 0.0228
# Epoch 441/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9923 - loss: 0.0258
# Epoch 442/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9926 - loss: 0.0169
# Epoch 443/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9917 - loss: 0.0174
# Epoch 444/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9942 - loss: 0.0274
# Epoch 445/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9913 - loss: 0.0294
# Epoch 446/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9910 - loss: 0.0358
# Epoch 447/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9924 - loss: 0.0393
# Epoch 448/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9927 - loss: 0.0212
# Epoch 449/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9969 - loss: 0.0127
# Epoch 450/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9972 - loss: 0.0182
# Epoch 451/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9992 - loss: 0.0067
# Epoch 452/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9941 - loss: 0.0159
# Epoch 453/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9909 - loss: 0.0263
# Epoch 454/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9966 - loss: 0.0104
# Epoch 455/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9974 - loss: 0.0152
# Epoch 456/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9941 - loss: 0.0132
# Epoch 457/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9892 - loss: 0.0589
# Epoch 458/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9926 - loss: 0.0345
# Epoch 459/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9929 - loss: 0.0243
# Epoch 460/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9946 - loss: 0.0158
# Epoch 461/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9898 - loss: 0.0376
# Epoch 462/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9951 - loss: 0.0215
# Epoch 463/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9915 - loss: 0.0277
# Epoch 464/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9955 - loss: 0.0138
# Epoch 465/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9887 - loss: 0.0307
# Epoch 466/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9954 - loss: 0.0153
# Epoch 467/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9991 - loss: 0.0062
# Epoch 468/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9955 - loss: 0.0130
# Epoch 469/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9983 - loss: 0.0078
# Epoch 470/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9967 - loss: 0.0150
# Epoch 471/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9947 - loss: 0.0198
# Epoch 472/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9964 - loss: 0.0083
# Epoch 473/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9898 - loss: 0.0272
# Epoch 474/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9931 - loss: 0.0358
# Epoch 475/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9907 - loss: 0.0426
# Epoch 476/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9935 - loss: 0.0277
# Epoch 477/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9939 - loss: 0.0217
# Epoch 478/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9959 - loss: 0.0162
# Epoch 479/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9928 - loss: 0.0270
# Epoch 480/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9966 - loss: 0.0125
# Epoch 481/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9954 - loss: 0.0145
# Epoch 482/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9978 - loss: 0.0115
# Epoch 483/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9962 - loss: 0.0119
# Epoch 484/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9939 - loss: 0.0180
# Epoch 485/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9965 - loss: 0.0174
# Epoch 486/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9944 - loss: 0.0285
# Epoch 487/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9946 - loss: 0.0166
# Epoch 488/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9980 - loss: 0.0087
# Epoch 489/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9962 - loss: 0.0120
# Epoch 490/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9974 - loss: 0.0102
# Epoch 491/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9981 - loss: 0.0107
# Epoch 492/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9927 - loss: 0.0327
# Epoch 493/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9964 - loss: 0.0123
# Epoch 494/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9902 - loss: 0.0337
# Epoch 495/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9971 - loss: 0.0134
# Epoch 496/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9953 - loss: 0.0179
# Epoch 497/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9977 - loss: 0.0121
# Epoch 498/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9951 - loss: 0.0110
# Epoch 499/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9953 - loss: 0.0149
# Epoch 500/500
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9958 - loss: 0.0164

# %% [markdown]
# ### Explanation of the Model
#
# The provided code defines and trains a sequential model using LSTM layers for a chatbot application. Here’s a detailed explanation of the model:
#
# #### Model Architecture
#
# 1. **Sequential Model**:
#    - The `Sequential` model is a linear stack of layers in Keras, allowing you to build a neural network layer by layer.
#
# 2. **LSTM Layers**:
#    - **LSTM (550 units)**: The first LSTM layer with 550 units. It receives input with a shape defined by `(training.shape[1], training.shape[2])` and returns sequences (`return_sequences=True`) to the next layer.
#    - **Dropout (0.2)**: A dropout layer with a dropout rate of 0.2, which helps prevent overfitting by randomly setting 20% of the input units to 0 at each update during training.
#    - **LSTM (512 units)**: The second LSTM layer with 512 units, also returning sequences.
#    - **Dropout (0.2)**: Another dropout layer to reduce overfitting.
#    - **LSTM (256 units)**: The third LSTM layer with 256 units, returning sequences.
#    - **Dropout (0.2)**: Dropout layer to reduce overfitting.
#    - **LSTM (128 units)**: The fourth LSTM layer with 128 units, returning sequences.
#    - **Dropout (0.2)**: Dropout layer to reduce overfitting.
#    - **LSTM (64 units)**: The fifth LSTM layer with 64 units. This layer does not return sequences (`return_sequences=False`), meaning it outputs the last output for each sample.
#    - **Dropout (0.2)**: Dropout layer to reduce overfitting.
#
# 3. **Dense Layer**:
#    - **Dense**: A fully connected (dense) layer with the number of units equal to the number of labels (`len(labels)`). The activation function used is `softmax`, which is suitable for multi-class classification.
#
# #### Model Summary
#
# - The `model.summary()` function prints a summary of the model, showing the output shape and number of parameters for each layer.
#
# #### Model Compilation
#
# - **Optimizer**: Adam optimizer with a learning rate of 0.001.
# - **Loss Function**: `categorical_crossentropy`, which is used for multi-class classification problems.
# - **Metrics**: `accuracy`, to monitor the accuracy during training and evaluation.
#
# #### Model Training
#
# - The model is trained using the `fit` method with the following parameters:
#   - **Training Data**: `training` (input data).
#   - **Output Data**: `output` (labels).
#   - **Epochs**: 500, indicating the number of times the model will iterate over the entire training dataset.
#   - **Verbose**: 1, to print progress and performance metrics during training.
#   - **Batch Size**: 4, specifying the number of samples that will be propagated through the network at once.
#
# #### Summary
#
# This model is designed to process sequential data using multiple LSTM layers, which are well-suited for capturing dependencies in sequential data, such as text. Dropout layers are used to mitigate overfitting, and a dense layer with softmax activation is used to produce the final class probabilities. The model is compiled with the Adam optimizer and trained over 500 epochs with a batch size of 4.

# %%
model.save("chatbot.h5")

# %% [markdown]
# ### Conclusion
#
# This project demonstrates the process of developing a simple yet effective chatbot using various datasets and a neural network model built with multiple LSTM layers. By leveraging the strengths of LSTM networks in handling sequential data, the chatbot is capable of understanding and generating appropriate responses to a wide range of user inputs.
#
# The following key points summarize the project:
#
# - **Data Utilization**: Multiple datasets were used to cover diverse intents and responses, enhancing the chatbot's versatility.
# - **Model Architecture**: The model consists of stacked LSTM layers, each followed by dropout layers to prevent overfitting, and a final dense layer with softmax activation for classification.
# - **Training and Evaluation**: The model was trained using the Adam optimizer and categorical cross-entropy loss function, with accuracy as the primary metric for performance evaluation.
# - **Implementation**: The trained model can be implemented in a simple chatbot application, providing a foundation for more complex conversational agents.
#
# This project showcases the potential of LSTM-based models in creating conversational AI systems and serves as a starting point for further enhancements and developments in the field of chatbot technology.
